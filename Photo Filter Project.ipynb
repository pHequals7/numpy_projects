# %%
# %matplotlib inline
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt

# %%
from skimage import data
photo_data = misc.imread('./photofilter/DP.jpg')

plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
import time
photo_data = misc.imread('./photofilter/DP.jpg')
plt.figure(figsize=(15,15))
plt.imshow(photo_data)
#red_mask = photo_data[:, : ,0] > 100
#grn_mask = photo_data[:,:,1] < 150
#comp_mask = np.logical_and(red_mask,grn_mask)
#photo_data[comp_mask] = 255
loop_mat = np.linspace(0,1,num=20)
for i in loop_mat:
    photo_data = photo_data*[1,i,1]
    time.sleep(1)
    plt.imshow(photo_data)
